# %% [markdown]
# # DMN Colab - Optimize
#
# Notebook Colab pour lancer l'optimisation d'une strategie sequence via `python -m dmn.cli.optimize_cli`.

# %%
import os
import subprocess
import sys
from pathlib import Path

REPO_URL = "https://github.com/figaroldamien/DMN.git"
REPO_DIR = Path("/content/DMN")

if not REPO_DIR.exists():
    subprocess.run(["git", "clone", REPO_URL, str(REPO_DIR)], check=True)
else:
    subprocess.run(["git", "-C", str(REPO_DIR), "pull", "--ff-only"], check=True)

subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", str(REPO_DIR / "requirements.txt")], check=True)
os.chdir(REPO_DIR)
print(f"Working directory: {REPO_DIR}")

# %%
CONFIG_PATH = "src/dmn/cli/config.example.toml"
STRATEGY = "DMN_LSTM_Sharpe_TurnPen"
MARKET = None
TICKER = "AAPL"
SECTOR = None
SUB_SECTOR = None
PRINT_CONFIG = True

# %%
env = os.environ.copy()
env["PYTHONPATH"] = f"{REPO_DIR / 'src'}:{env.get('PYTHONPATH', '')}"

cmd = [sys.executable, "-m", "dmn.cli.optimize_cli", "--config", CONFIG_PATH, "--strategy", STRATEGY]
if TICKER:
    cmd.extend(["--ticker", TICKER])
elif MARKET:
    cmd.extend(["--market", MARKET])
if SECTOR:
    cmd.extend(["--sector", SECTOR])
if SUB_SECTOR:
    cmd.extend(["--sub-sector", SUB_SECTOR])
if not PRINT_CONFIG:
    cmd.append("--no-print-config")

print("Running:", " ".join(cmd))
subprocess.run(cmd, check=True, env=env)
